# %% [markdown]
# # 06 - Calcolatore
#
# Notebook per eseguire il calcolatore didattico con la nuova struttura `scripts/` e `output/`.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
for path in [REPO_ROOT / 'scripts', REPO_ROOT / 'scripts' / 'src']:
    if str(path) not in sys.path:
        sys.path.append(str(path))

from pension_paid_calculator import run_pension_paid_calculator

run_pension_paid_calculator()
